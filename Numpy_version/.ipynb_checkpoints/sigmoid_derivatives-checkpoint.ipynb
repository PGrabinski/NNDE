# %%
import numpy as np
import nnde
import matplotlib.pyplot as plt

# %% [markdown]
# # Test of the sigmoid derivatives
#
# [Derivation](https://joepatmckenna.github.io/calculus/derivative/sigmoid%20function/linear%20albegra/2018/01/20/sigmoid-derivs/)

# %%
for i in range(10):
  plt.plot(np.arange(-10,10,0.01),nnde.sigmoid(np.arange(-10,10,0.01),i))
  plt.show()
